# %%
import pygeostat as gs

# %% [markdown]
# Importing walker lake

# %%
walker_lake = gs.DataFile('data/walker_lake.txt', x='X', y='Y')

# %%
walker_lake.head()
# Out:
#       X     Y       Co  Ni
# 0  11.0   8.0   0.0000 NaN
# 1   8.0  30.0   0.0000 NaN
# 2   9.0  48.0   6.0588 NaN
# 3   8.0  69.0  11.7288 NaN
# 4   9.0  90.0  11.1267 NaN

# %%
_ = gs.location_plot(walker_lake, var='Co', output_file='images/walker.png')

# %% [markdown]
# Sampling walker lake and getting the complement

# %%
import numpy as np
idxs = np.random.randint(0, walker_lake.shape[0], 100)
comp_idx = []
for i in range(walker_lake.shape[0]):
    if i not in idxs:
        comp_idx.append(i)
comp_idx = np.array(comp_idx)

# %%
sampled = walker_lake.data.loc[idxs]
sampled = gs.DataFile(data=sampled, x='X', y='Y')
gs.write_gslib(sampled, 'upgradable_data/sampled_walker.dat')
sampled = gs.DataFile('upgradable_data/sampled_walker.dat')

# %%
complement = walker_lake.data.loc[comp_idx]
complement = gs.DataFile(data=complement, x='X', y='Y')
gs.write_gslib(complement, 'data/complement.dat')

# %%
_ = gs.location_plot(sampled, var='Co', output_file='images/walker.png')

# %% [markdown]
# Kriging initial model

# %%
grid = walker_lake.infergriddef(blksize=(5, 5, 1))

# %%
kt3d = gs.Program('kt3d', getpar=True)
# Out:
# Unable to find the provided program! Trying to use the executable pool shipped with pygeostat!
# C:\Users\Roberto Rolo\Documents\GitHub\model_updater\tmp3zfk_c98\kt3d.par has been copied to the clipboard

# %%
parstr = """                  Parameters for KT3D
                  *******************

START OF PARAMETERS:
{input_data}              -file with data
0  1  2  0  3  0                 -   columns for DH,X,Y,Z,var,sec var
-1.0e21   1.0e21                 -   trimming limits
0                                -option: 0=grid, 1=cross, 2=jackknife
xvk.dat                          -file with jackknife data
1   2   0    3    0              -   columns for X,Y,Z,vr and sec var
3                                -debugging level: 0,1,2,3
outputs/kt3d.dbg                         -file for debugging output
{outfl}                         -file for kriged output
{griddef}
1    1      1                    -x,y and z block discretization
1    12                           -min, max data for kriging
0                                -max per octant (0-> not used)
300.0  300.0  300.0                 -maximum search radii
 160.0   0.0   0.0                 -angles for search ellipsoid
1     2.302                      -0=SK,1=OK,2=non-st SK,3=exdrift
0 0 0 0 0 0 0 0 0                -drift: x,y,z,xx,yy,zz,xy,xz,zy
0                                -0, variable; 1, estimate trend
extdrift.dat                     -gridded file with drift/mean
4                                -  column number in gridded file
1    0.01                         -nst, nugget effect
1    0.99 160   0.0   0.0        -it,cc,ang1,ang2,ang3
         50  0.0  0.0        -a_hmax, a_hmin, a_vert
"""

pars = dict(input_data=sampled.flname,
            outfl = 'outputs/initial_model.out',
            griddef = grid)
kt3d.run(parstr=parstr.format(**pars),quiet=False, liveoutput=True)
# Out:
# Calling:  ['C:\\Users\\Roberto Rolo\\anaconda3\\envs\\geostat\\lib\\site-packages\\pygeostat\\executable\\kt3d', 'temp']
#
# KT3D Version: 2.907
#
#  data file = upgradable_data/sampled_walker.dat
#  columns =           0           1           2           0           3
#           0
#  trimming limits =   -1.000000E+21    1.000000E+21
#  kriging option =           0
#  jackknife data file = xvk.dat
#  columns =           1           2           0           3           0
#  debugging level =           3
#  debugging file = outputs/kt3d.dbg
#  output file = outputs/initial_model.out
#  nx, xmn, xsiz =          51        5.500000        5.000000
#  ny, ymn, ysiz =          59        5.500000        5.000000
#  nz, zmn, zsiz =           1    5.000000E-01        1.000000
#  block discretization:          1           1           1
#  ndmin,ndmax =           1          12
#  max per octant =           0
#  search radii =      300.000000      300.000000      300.000000
#  search anisotropy angles =      160.000000    0.000000E+00    0.000000E+00
#  ktype, skmean =          1        2.302000
#  drift terms =           0           0           0           0           0
#           0           0           0           0
#  itrend =           0
#  external drift file = extdrift.dat
#  variable in external drift file =           4
#  nst, c0 =           1    1.000000E-02
#  it,cc,ang[1,2,3];           1    9.900000E-01      160.000000    0.000000E+00
#    0.000000E+00
#  a1 a2 a3:       50.000000    0.000000E+00    0.000000E+00
# Data for KT3D: Variable number           3
#   Number   =         100
#   Average  =       10.820760
#   Variance =       61.210390
# Setting up rotation matrices for variogram and search
# Setting up super block search strategy
#
# Working on the kriging
#   currently on estimate       300
#   currently on estimate       600
#   currently on estimate       900
#   currently on estimate      1200
#   currently on estimate      1500
#   currently on estimate      1800
#   currently on estimate      2100
#   currently on estimate      2400
#   currently on estimate      2700
#   currently on estimate      3000
#
# stimated        582 blocks
#  average     15.1274
#  variance     8.7522
#
#
# KT3D Version: 2.907 Finished
#
# Stop - Program terminated.

# %%
model = gs.DataFile('outputs/initial_model.out', griddef=grid)

# %%
_ = gs.slice_plot(model, griddef=grid, output_file='images/initial_model.png')

# %% [markdown]
# Starting to upgrade the model live

# %%
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

class MyHandler(FileSystemEventHandler):
    def __init__(self):
        self.c = 0
    
    def on_modified(self, event):
        print(f'Event type: {event.event_type}  path : {event.src_path}')

        upgradaded_sampled_walker = gs.DataFile('upgradable_data/sampled_walker.dat')
        pars_n = dict(input_data=upgradaded_sampled_walker.flname,
                    outfl = 'outputs/model_{}.out'.format(self.c),
                    griddef = grid)
        kt3d.run(parstr=parstr.format(**pars_n),quiet=False, liveoutput=False)
        model = gs.DataFile('outputs/model_{}.out'.format(self.c), griddef=grid)
        _ = gs.slice_plot(model, griddef=grid, output_file='images/model_{}.png'.format(self.c))
        _ = gs.location_plot(upgradaded_sampled_walker, var='Co', output_file='images/walker_{}.png'.format(self.c))

        self.c = self.c + 1

event_handler = MyHandler()
observer = Observer()
observer.schedule(event_handler, path='upgradable_data', recursive=False)
observer.start()
print('I am Listening...')

try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    observer.stop()
observer.join()
